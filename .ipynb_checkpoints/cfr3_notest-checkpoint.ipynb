# %%
# VARIABLE DESCRIPTIONS:
# 1  survival        Survival
#                    (0 = No; 1 = Yes)
# 2  pclass          Passenger Class
#                    (1 = 1st; 2 = 2nd; 3 = 3rd)
# 3  name            Name
# 4  sex             Sex
# 5  age             Age
# 6  sibsp           Number of Siblings/Spouses Aboard
# 7  parch           Number of Parents/Children Aboard
# 8  ticket          Ticket Number
# 9  fare            Passenger Fare
# 10 cabin           Cabin
# 11 embarked        Port of Embarkation
#                    (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
# %matplotlib inline
# %config IPCompleter.greedy=True

import numpy as np
import matplotlib as matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pandas as pd

# %%
train_path='./train.csv'
test_path='./test.csv'

# import data
traindf_raw = pd.read_csv(train_path)
testdf_raw = pd.read_csv(test_path)

# %%
from titanic_fun import *

# Clean the training values
traindf=clean_data(traindf_raw)
testdf=clean_data(testdf_raw)
# Out:
# /Users/Gambero/anaconda/lib/python3.5/site-packages/scipy/stats/stats.py:257: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
#CatVar=['Pclass','Sex','Embarked','NumCabins','Title','CabinNew','AgeBinned','FareBinned']
#ScaleVar=['SibSp','Parch','FamSize']
#NormVar=['Age','Log10Fare','FareAgeRatio','FareFam','AgeClassInt']
    
CatVar=['Pclass','Sex','Embarked','Title','FareBinned','NumCabins']
ScaleVar=['SibSp','Parch','FamSize']
NormVar=['FareAgeRatio','FareFam','AgeClassInt','Age']    

traindf=NewFeatures(traindf)
Xdf=preprocessFeatures(traindf,CatVar,ScaleVar,NormVar)

testdf=NewFeatures(testdf)
X_testdf=preprocessFeatures(testdf,CatVar,ScaleVar,NormVar)

X,X_test,labels=FeaturesNumpy(Xdf,X_testdf)

# Survivors
y=np.squeeze(traindf['Survived'].as_matrix())

# %%
from sklearn.cross_validation import train_test_split

# Split the dataset in two equal parts
X_train, X_cvtest, y_train, y_cvtest = train_test_split(X, y, test_size=0.005, random_state=42)

# %%
# number of training examples and features
m,n=np.shape(X_train)
print('m =',m,'n=',n)
# Out:
# m = 886 n= 41

# %%
# Null accuracy
null_accuracy=1-y.mean()

print('Null accuracy',null_accuracy)
# Out:
# Null accuracy 0.616161616162

# %%
# Grid search CV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.learning_curve import validation_curve


def DoGridSearch(estimator,tuned_parameters,X,y,X_test,y_test):
    print("# Tuning hyper-parameters for accuracy")
    print()

    clf = GridSearchCV(estimator, tuned_parameters, cv=10,
                           scoring='accuracy',n_jobs=4)
    clf.fit(X, y)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    for params, mean_score, scores in clf.grid_scores_:
        print("%0.3f (+/-%0.03f) for %r"
                  % (mean_score, scores.std() * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    
    return clf;

from sklearn.learning_curve import validation_curve

def DoValidationCurve(estimator,param_name,param_range,X,y):

    train_scores, test_scores = validation_curve(estimator, X, y,
                                                 param_name=param_name, param_range=param_range,
                                                 cv=10, scoring="accuracy", n_jobs=4)

    # Compute mean and std
    train_scores_mean=np.mean(train_scores, axis=1)
    train_scores_std=np.std(train_scores, axis=1)
    test_scores_mean=np.mean(test_scores, axis=1)
    test_scores_std=np.std(test_scores, axis=1)

    # Plot validation curve
    plt.figure(figsize=(10,6))
    plt.title("Validation Curve with "+str(estimator))
    plt.xlabel(param_name)
    plt.ylabel("Score")
    plt.ylim(0.5, 0.95)

    plt.semilogx(param_range, train_scores_mean, label="Training score", color="r")
    plt.fill_between(param_range, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.2, color="r")
    plt.semilogx(param_range, test_scores_mean, label="Cv score", color="g")
    plt.fill_between(param_range, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.2, color="g")
    plt.legend(loc="best")
    plt.grid()
    plt.show()
    
    return

# %%
# Grid search CV
from sklearn.linear_model import LogisticRegression

####### LOGISTIC REGRESSION ##########
# Define C array
Cs=[0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1,3,6,10,30,60,100]

# Set the parameters by cross-validation
tuned_parameters = [{'C':Cs}]

log_reg=DoGridSearch(LogisticRegression(),tuned_parameters,X_train,y_train,X_cvtest,y_cvtest)
DoValidationCurve(LogisticRegression(),'C',Cs,X_train,y_train)
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'C': 3}
#
# Grid scores on development set:
#
# 0.726 (+/-0.062) for {'C': 0.001}
# 0.752 (+/-0.083) for {'C': 0.003}
# 0.784 (+/-0.108) for {'C': 0.006}
# 0.791 (+/-0.120) for {'C': 0.01}
# 0.817 (+/-0.109) for {'C': 0.03}
# 0.815 (+/-0.107) for {'C': 0.06}
# 0.818 (+/-0.106) for {'C': 0.1}
# 0.815 (+/-0.101) for {'C': 0.3}
# 0.814 (+/-0.098) for {'C': 0.6}
# 0.819 (+/-0.094) for {'C': 1}
# 0.821 (+/-0.096) for {'C': 3}
# 0.818 (+/-0.103) for {'C': 6}
# 0.818 (+/-0.107) for {'C': 10}
# 0.818 (+/-0.105) for {'C': 30}
# 0.817 (+/-0.103) for {'C': 60}
# 0.816 (+/-0.099) for {'C': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00         2
#           1       1.00      1.00      1.00         3
#
# avg / total       1.00      1.00      1.00         5

# %%
# Grid search CV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

####### SVM ##########
# Define C array
Cs=[0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1,3,6,10]
gammas=[0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1]

# Set the parameters by cross-validation
tuned_parameters = [{'C':Cs,
                    'gamma':gammas}]

svm1=DoGridSearch(SVC(),tuned_parameters,X_train,y_train,X_cvtest,y_cvtest)
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'C': 3, 'gamma': 0.06}
#
# Grid scores on development set:
#
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.001}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.003}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.006}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.01}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.03}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.06}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.1}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.3}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 0.6}
# 0.617 (+/-0.004) for {'C': 0.001, 'gamma': 1}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.001}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.003}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.006}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.01}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.03}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.06}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.1}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.3}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 0.6}
# 0.617 (+/-0.004) for {'C': 0.003, 'gamma': 1}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.001}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.003}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.006}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.01}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.03}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.06}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.1}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.3}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 0.6}
# 0.617 (+/-0.004) for {'C': 0.006, 'gamma': 1}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.001}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.003}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.006}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.01}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.03}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.06}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.1}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.3}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 0.6}
# 0.617 (+/-0.004) for {'C': 0.01, 'gamma': 1}
# 0.617 (+/-0.004) for {'C': 0.03, 'gamma': 0.001}
# 0.617 (+/-0.004) for {'C': 0.03, 'gamma': 0.003}
# 0.617 (+/-0.004) for {'C': 0.03, 'gamma': 0.006}
# 0.617 (+/-0.004) for {'C': 0.03, 'gamma': 0.01}
# 0.677 (+/-0.054) for {'C': 0.03, 'gamma': 0.03}
# 0.746 (+/-0.053) for {'C': 0.03, 'gamma': 0.06}
# 0.780 (+/-0.105) for {'C': 0.03, 'gamma': 0.1}
# 0.641 (+/-0.037) for {'C': 0.03, 'gamma': 0.3}
# 0.617 (+/-0.004) for {'C': 0.03, 'gamma': 0.6}
# 0.617 (+/-0.004) for {'C': 0.03, 'gamma': 1}
# 0.617 (+/-0.004) for {'C': 0.06, 'gamma': 0.001}
# 0.617 (+/-0.004) for {'C': 0.06, 'gamma': 0.003}
# 0.617 (+/-0.004) for {'C': 0.06, 'gamma': 0.006}
# 0.641 (+/-0.036) for {'C': 0.06, 'gamma': 0.01}
# 0.788 (+/-0.133) for {'C': 0.06, 'gamma': 0.03}
# 0.793 (+/-0.116) for {'C': 0.06, 'gamma': 0.06}
# 0.791 (+/-0.120) for {'C': 0.06, 'gamma': 0.1}
# 0.783 (+/-0.122) for {'C': 0.06, 'gamma': 0.3}
# 0.658 (+/-0.023) for {'C': 0.06, 'gamma': 0.6}
# 0.617 (+/-0.009) for {'C': 0.06, 'gamma': 1}
# 0.617 (+/-0.004) for {'C': 0.1, 'gamma': 0.001}
# 0.617 (+/-0.004) for {'C': 0.1, 'gamma': 0.003}
# 0.661 (+/-0.051) for {'C': 0.1, 'gamma': 0.006}
# 0.734 (+/-0.062) for {'C': 0.1, 'gamma': 0.01}
# 0.797 (+/-0.118) for {'C': 0.1, 'gamma': 0.03}
# 0.792 (+/-0.119) for {'C': 0.1, 'gamma': 0.06}
# 0.796 (+/-0.123) for {'C': 0.1, 'gamma': 0.1}
# 0.791 (+/-0.104) for {'C': 0.1, 'gamma': 0.3}
# 0.802 (+/-0.063) for {'C': 0.1, 'gamma': 0.6}
# 0.656 (+/-0.027) for {'C': 0.1, 'gamma': 1}
# 0.620 (+/-0.008) for {'C': 0.3, 'gamma': 0.001}
# 0.731 (+/-0.055) for {'C': 0.3, 'gamma': 0.003}
# 0.795 (+/-0.119) for {'C': 0.3, 'gamma': 0.006}
# 0.797 (+/-0.119) for {'C': 0.3, 'gamma': 0.01}
# 0.797 (+/-0.115) for {'C': 0.3, 'gamma': 0.03}
# 0.805 (+/-0.123) for {'C': 0.3, 'gamma': 0.06}
# 0.810 (+/-0.114) for {'C': 0.3, 'gamma': 0.1}
# 0.822 (+/-0.075) for {'C': 0.3, 'gamma': 0.3}
# 0.822 (+/-0.086) for {'C': 0.3, 'gamma': 0.6}
# 0.819 (+/-0.083) for {'C': 0.3, 'gamma': 1}
# 0.683 (+/-0.050) for {'C': 0.6, 'gamma': 0.001}
# 0.795 (+/-0.117) for {'C': 0.6, 'gamma': 0.003}
# 0.797 (+/-0.119) for {'C': 0.6, 'gamma': 0.006}
# 0.796 (+/-0.123) for {'C': 0.6, 'gamma': 0.01}
# 0.806 (+/-0.120) for {'C': 0.6, 'gamma': 0.03}
# 0.813 (+/-0.114) for {'C': 0.6, 'gamma': 0.06}
# 0.824 (+/-0.099) for {'C': 0.6, 'gamma': 0.1}
# 0.828 (+/-0.079) for {'C': 0.6, 'gamma': 0.3}
# 0.825 (+/-0.076) for {'C': 0.6, 'gamma': 0.6}
# 0.812 (+/-0.077) for {'C': 0.6, 'gamma': 1}
# 0.737 (+/-0.070) for {'C': 1, 'gamma': 0.001}
# 0.793 (+/-0.121) for {'C': 1, 'gamma': 0.003}
# 0.791 (+/-0.121) for {'C': 1, 'gamma': 0.006}
# 0.797 (+/-0.122) for {'C': 1, 'gamma': 0.01}
# 0.812 (+/-0.116) for {'C': 1, 'gamma': 0.03}
# 0.826 (+/-0.089) for {'C': 1, 'gamma': 0.06}
# 0.823 (+/-0.074) for {'C': 1, 'gamma': 0.1}
# 0.819 (+/-0.072) for {'C': 1, 'gamma': 0.3}
# 0.817 (+/-0.062) for {'C': 1, 'gamma': 0.6}
# 0.814 (+/-0.067) for {'C': 1, 'gamma': 1}
# 0.792 (+/-0.123) for {'C': 3, 'gamma': 0.001}
# 0.790 (+/-0.119) for {'C': 3, 'gamma': 0.003}
# 0.797 (+/-0.117) for {'C': 3, 'gamma': 0.006}
# 0.807 (+/-0.116) for {'C': 3, 'gamma': 0.01}
# 0.833 (+/-0.089) for {'C': 3, 'gamma': 0.03}
# 0.835 (+/-0.072) for {'C': 3, 'gamma': 0.06}
# 0.828 (+/-0.074) for {'C': 3, 'gamma': 0.1}
# 0.824 (+/-0.061) for {'C': 3, 'gamma': 0.3}
# 0.816 (+/-0.063) for {'C': 3, 'gamma': 0.6}
# 0.813 (+/-0.063) for {'C': 3, 'gamma': 1}
# 0.788 (+/-0.123) for {'C': 6, 'gamma': 0.001}
# 0.795 (+/-0.127) for {'C': 6, 'gamma': 0.003}
# 0.808 (+/-0.121) for {'C': 6, 'gamma': 0.006}
# 0.815 (+/-0.114) for {'C': 6, 'gamma': 0.01}
# 0.832 (+/-0.083) for {'C': 6, 'gamma': 0.03}
# 0.827 (+/-0.074) for {'C': 6, 'gamma': 0.06}
# 0.818 (+/-0.066) for {'C': 6, 'gamma': 0.1}
# 0.826 (+/-0.060) for {'C': 6, 'gamma': 0.3}
# 0.819 (+/-0.070) for {'C': 6, 'gamma': 0.6}
# 0.804 (+/-0.067) for {'C': 6, 'gamma': 1}
# 0.789 (+/-0.122) for {'C': 10, 'gamma': 0.001}
# 0.802 (+/-0.128) for {'C': 10, 'gamma': 0.003}
# 0.815 (+/-0.118) for {'C': 10, 'gamma': 0.006}
# 0.827 (+/-0.095) for {'C': 10, 'gamma': 0.01}
# 0.835 (+/-0.068) for {'C': 10, 'gamma': 0.03}
# 0.821 (+/-0.069) for {'C': 10, 'gamma': 0.06}
# 0.818 (+/-0.061) for {'C': 10, 'gamma': 0.1}
# 0.821 (+/-0.060) for {'C': 10, 'gamma': 0.3}
# 0.814 (+/-0.081) for {'C': 10, 'gamma': 0.6}
# 0.802 (+/-0.062) for {'C': 10, 'gamma': 1}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00         2
#           1       1.00      1.00      1.00         3
#
# avg / total       1.00      1.00      1.00         5

# %%
Cs=[0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1,3,6,10]
DoValidationCurve(SVC(gamma=0.06),'C',Cs,X_train,y_train)
DoValidationCurve(SVC(C=3),'gamma',gammas,X_train,y_train)

# %%
from sklearn.neighbors import KNeighborsClassifier

####### KNN ##########
# Define C array
nn=np.arange(1,50)

# Set the parameters by cross-validation
tuned_parameters = [{'n_neighbors':nn,
                    'weights':['uniform','distance']}]

knn=DoGridSearch(KNeighborsClassifier(),tuned_parameters,X_train,y_train,X_cvtest,y_cvtest)
DoValidationCurve(KNeighborsClassifier(weights='uniform'),'n_neighbors',nn,X_train,y_train)
DoValidationCurve(KNeighborsClassifier(weights='distance'),'n_neighbors',nn,X_train,y_train)
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'n_neighbors': 36, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.772 (+/-0.060) for {'n_neighbors': 1, 'weights': 'uniform'}
# 0.772 (+/-0.060) for {'n_neighbors': 1, 'weights': 'distance'}
# 0.777 (+/-0.086) for {'n_neighbors': 2, 'weights': 'uniform'}
# 0.772 (+/-0.068) for {'n_neighbors': 2, 'weights': 'distance'}
# 0.801 (+/-0.059) for {'n_neighbors': 3, 'weights': 'uniform'}
# 0.793 (+/-0.062) for {'n_neighbors': 3, 'weights': 'distance'}
# 0.802 (+/-0.059) for {'n_neighbors': 4, 'weights': 'uniform'}
# 0.798 (+/-0.075) for {'n_neighbors': 4, 'weights': 'distance'}
# 0.824 (+/-0.057) for {'n_neighbors': 5, 'weights': 'uniform'}
# 0.808 (+/-0.077) for {'n_neighbors': 5, 'weights': 'distance'}
# 0.809 (+/-0.063) for {'n_neighbors': 6, 'weights': 'uniform'}
# 0.800 (+/-0.077) for {'n_neighbors': 6, 'weights': 'distance'}
# 0.822 (+/-0.065) for {'n_neighbors': 7, 'weights': 'uniform'}
# 0.805 (+/-0.066) for {'n_neighbors': 7, 'weights': 'distance'}
# 0.813 (+/-0.059) for {'n_neighbors': 8, 'weights': 'uniform'}
# 0.806 (+/-0.067) for {'n_neighbors': 8, 'weights': 'distance'}
# 0.816 (+/-0.067) for {'n_neighbors': 9, 'weights': 'uniform'}
# 0.806 (+/-0.064) for {'n_neighbors': 9, 'weights': 'distance'}
# 0.810 (+/-0.071) for {'n_neighbors': 10, 'weights': 'uniform'}
# 0.805 (+/-0.058) for {'n_neighbors': 10, 'weights': 'distance'}
# 0.808 (+/-0.065) for {'n_neighbors': 11, 'weights': 'uniform'}
# 0.805 (+/-0.052) for {'n_neighbors': 11, 'weights': 'distance'}
# 0.807 (+/-0.065) for {'n_neighbors': 12, 'weights': 'uniform'}
# 0.806 (+/-0.067) for {'n_neighbors': 12, 'weights': 'distance'}
# 0.809 (+/-0.092) for {'n_neighbors': 13, 'weights': 'uniform'}
# 0.809 (+/-0.070) for {'n_neighbors': 13, 'weights': 'distance'}
# 0.799 (+/-0.088) for {'n_neighbors': 14, 'weights': 'uniform'}
# 0.801 (+/-0.056) for {'n_neighbors': 14, 'weights': 'distance'}
# 0.799 (+/-0.077) for {'n_neighbors': 15, 'weights': 'uniform'}
# 0.796 (+/-0.057) for {'n_neighbors': 15, 'weights': 'distance'}
# 0.798 (+/-0.086) for {'n_neighbors': 16, 'weights': 'uniform'}
# 0.798 (+/-0.070) for {'n_neighbors': 16, 'weights': 'distance'}
# 0.795 (+/-0.097) for {'n_neighbors': 17, 'weights': 'uniform'}
# 0.795 (+/-0.079) for {'n_neighbors': 17, 'weights': 'distance'}
# 0.800 (+/-0.094) for {'n_neighbors': 18, 'weights': 'uniform'}
# 0.800 (+/-0.074) for {'n_neighbors': 18, 'weights': 'distance'}
# 0.798 (+/-0.095) for {'n_neighbors': 19, 'weights': 'uniform'}
# 0.799 (+/-0.082) for {'n_neighbors': 19, 'weights': 'distance'}
# 0.800 (+/-0.103) for {'n_neighbors': 20, 'weights': 'uniform'}
# 0.797 (+/-0.086) for {'n_neighbors': 20, 'weights': 'distance'}
# 0.798 (+/-0.104) for {'n_neighbors': 21, 'weights': 'uniform'}
# 0.800 (+/-0.086) for {'n_neighbors': 21, 'weights': 'distance'}
# 0.801 (+/-0.108) for {'n_neighbors': 22, 'weights': 'uniform'}
# 0.796 (+/-0.088) for {'n_neighbors': 22, 'weights': 'distance'}
# 0.799 (+/-0.110) for {'n_neighbors': 23, 'weights': 'uniform'}
# 0.797 (+/-0.086) for {'n_neighbors': 23, 'weights': 'distance'}
# 0.798 (+/-0.097) for {'n_neighbors': 24, 'weights': 'uniform'}
# 0.793 (+/-0.082) for {'n_neighbors': 24, 'weights': 'distance'}
# 0.801 (+/-0.100) for {'n_neighbors': 25, 'weights': 'uniform'}
# 0.792 (+/-0.077) for {'n_neighbors': 25, 'weights': 'distance'}
# 0.805 (+/-0.105) for {'n_neighbors': 26, 'weights': 'uniform'}
# 0.790 (+/-0.081) for {'n_neighbors': 26, 'weights': 'distance'}
# 0.804 (+/-0.111) for {'n_neighbors': 27, 'weights': 'uniform'}
# 0.797 (+/-0.084) for {'n_neighbors': 27, 'weights': 'distance'}
# 0.807 (+/-0.103) for {'n_neighbors': 28, 'weights': 'uniform'}
# 0.793 (+/-0.084) for {'n_neighbors': 28, 'weights': 'distance'}
# 0.804 (+/-0.107) for {'n_neighbors': 29, 'weights': 'uniform'}
# 0.799 (+/-0.082) for {'n_neighbors': 29, 'weights': 'distance'}
# 0.808 (+/-0.090) for {'n_neighbors': 30, 'weights': 'uniform'}
# 0.799 (+/-0.079) for {'n_neighbors': 30, 'weights': 'distance'}
# 0.810 (+/-0.088) for {'n_neighbors': 31, 'weights': 'uniform'}
# 0.804 (+/-0.080) for {'n_neighbors': 31, 'weights': 'distance'}
# 0.809 (+/-0.080) for {'n_neighbors': 32, 'weights': 'uniform'}
# 0.805 (+/-0.073) for {'n_neighbors': 32, 'weights': 'distance'}
# 0.810 (+/-0.094) for {'n_neighbors': 33, 'weights': 'uniform'}
# 0.805 (+/-0.085) for {'n_neighbors': 33, 'weights': 'distance'}
# 0.817 (+/-0.104) for {'n_neighbors': 34, 'weights': 'uniform'}
# 0.806 (+/-0.083) for {'n_neighbors': 34, 'weights': 'distance'}
# 0.818 (+/-0.103) for {'n_neighbors': 35, 'weights': 'uniform'}
# 0.809 (+/-0.087) for {'n_neighbors': 35, 'weights': 'distance'}
# 0.825 (+/-0.094) for {'n_neighbors': 36, 'weights': 'uniform'}
# 0.808 (+/-0.082) for {'n_neighbors': 36, 'weights': 'distance'}
# 0.824 (+/-0.103) for {'n_neighbors': 37, 'weights': 'uniform'}
# 0.808 (+/-0.086) for {'n_neighbors': 37, 'weights': 'distance'}
# 0.823 (+/-0.098) for {'n_neighbors': 38, 'weights': 'uniform'}
# 0.808 (+/-0.085) for {'n_neighbors': 38, 'weights': 'distance'}
# 0.818 (+/-0.089) for {'n_neighbors': 39, 'weights': 'uniform'}
# 0.806 (+/-0.085) for {'n_neighbors': 39, 'weights': 'distance'}
# 0.814 (+/-0.088) for {'n_neighbors': 40, 'weights': 'uniform'}
# 0.804 (+/-0.083) for {'n_neighbors': 40, 'weights': 'distance'}
# 0.814 (+/-0.095) for {'n_neighbors': 41, 'weights': 'uniform'}
# 0.804 (+/-0.087) for {'n_neighbors': 41, 'weights': 'distance'}
# 0.815 (+/-0.090) for {'n_neighbors': 42, 'weights': 'uniform'}
# 0.804 (+/-0.081) for {'n_neighbors': 42, 'weights': 'distance'}
# 0.819 (+/-0.090) for {'n_neighbors': 43, 'weights': 'uniform'}
# 0.808 (+/-0.077) for {'n_neighbors': 43, 'weights': 'distance'}
# 0.817 (+/-0.086) for {'n_neighbors': 44, 'weights': 'uniform'}
# 0.806 (+/-0.076) for {'n_neighbors': 44, 'weights': 'distance'}
# 0.818 (+/-0.089) for {'n_neighbors': 45, 'weights': 'uniform'}
# 0.807 (+/-0.080) for {'n_neighbors': 45, 'weights': 'distance'}
# 0.817 (+/-0.092) for {'n_neighbors': 46, 'weights': 'uniform'}
# 0.804 (+/-0.081) for {'n_neighbors': 46, 'weights': 'distance'}
# 0.815 (+/-0.100) for {'n_neighbors': 47, 'weights': 'uniform'}
# 0.804 (+/-0.078) for {'n_neighbors': 47, 'weights': 'distance'}
# 0.809 (+/-0.093) for {'n_neighbors': 48, 'weights': 'uniform'}
# 0.804 (+/-0.096) for {'n_neighbors': 48, 'weights': 'distance'}
# 0.810 (+/-0.108) for {'n_neighbors': 49, 'weights': 'uniform'}
# 0.809 (+/-0.101) for {'n_neighbors': 49, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67         2
#           1       1.00      0.33      0.50         3
#
# avg / total       0.80      0.60      0.57         5

# %%
# Learning curves
from compare_models import *

model_1=LogisticRegression(**log_reg.best_params_)
model_1.fit(X_train,y_train)

model_2=SVC(**svm1.best_params_,probability=True)
model_2.fit(X_train,y_train)

model_3=KNeighborsClassifier(**knn.best_params_)
model_3.fit(X_train,y_train)

# Compare the two models
models=[model_1,model_2]

CfrLearningCurves(models,X_train,y_train)

# %%
CfrROCCurves(models,X_train,y_train)

i=0
for model in models:
    i=i+1
    print('model_'+str(i)+' accuracy:',model.score(X_cvtest,y_cvtest))
# Out:
# ----------------------------- model_1 ------------------------------
# Confusion matrix
# [[483  64]
#  [ 76 263]]
# NullAccuracy:                      0.617381489842
# Accuracy   : (TP+TN)/(TP+TN+FP+FN) 0.841986455982
# Class Error: (FP+FN)/(TP+TN+FP+FN) 0.158013544018
# Sensitivity:      TP/(TP+FN)       0.77581120944
# Specificity:      TN/(TN+FP)       0.882998171846
# FP rate    :      FP/(FP+TN)       0.117001828154
# Precision  :      TP/(FP+TP)       0.804281345566
# F1 score   :                       0.78978978979
# AUC        :                       0.882793246078
#
# ----------------------------- model_2 ------------------------------
# Confusion matrix
# [[502  45]
#  [ 82 257]]
# NullAccuracy:                      0.617381489842
# Accuracy   : (TP+TN)/(TP+TN+FP+FN) 0.856659142212
# Class Error: (FP+FN)/(TP+TN+FP+FN) 0.143340857788
# Sensitivity:      TP/(TP+FN)       0.758112094395
# Specificity:      TN/(TN+FP)       0.91773308958
# FP rate    :      FP/(FP+TN)       0.0822669104205
# Precision  :      TP/(FP+TP)       0.850993377483
# F1 score   :                       0.801872074883
# AUC        :                       0.906761471798
# model_1 accuracy: 1.0
# model_2 accuracy: 1.0

# %%
# create a submission file for kaggle
y_pred_test=model_1.predict(X_test)
predictiondf = pd.DataFrame(testdf['PassengerId'])
predictiondf['Survived']=y_pred_test
#predictiondf.to_csv('./prediction_cfr3_model1.csv',
#           index=False)

y_pred_test=model_2.predict(X_test)
predictiondf = pd.DataFrame(testdf['PassengerId'])
predictiondf['Survived']=y_pred_test
#predictiondf.to_csv('./prediction_cfr3_model2.csv',
#           index=False)
